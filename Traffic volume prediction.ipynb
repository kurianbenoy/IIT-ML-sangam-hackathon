# %%
import pandas as pd
import numpy as np

# %%
sample_sub = pd.read_csv('sample_submission.csv')

# %%
sample_sub.head()
# Out:
#              date_time  traffic_volume
# 0  1969-05-17 21:00:00             500
# 1  1969-05-17 21:00:00             530
# 2  1969-05-17 21:00:00             545
# 3  1969-05-17 22:00:00             750

# %%
df = pd.read_csv('Train.csv')

# %%
df.head(10)
# Out:
#              date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2012-10-02 09:00:00       None                  121        89           2
# 1  2012-10-02 10:00:00       None                  178        67           3
# 2  2012-10-02 11:00:00       None                  113        66           3
# 3  2012-10-02 12:00:00       None                   20        66           3
# 4  2012-10-02 13:00:00       None                  281        65           3
# 5  2012-10-02 14:00:00       None                   23        65           3
# 6  2012-10-02 15:00:00       None                  184        64           3
# 7  2012-10-02 16:00:00       None                  167        64           3
# 8  2012-10-02 17:00:00       None                  119        63           3
# 9  2012-10-02 18:00:00       None                  161        63           3
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# ...

# %%
df.shape
# Out:
# (33750, 15)

# %%
df['weather_type'].unique()
# Out:
# array(['Clouds', 'Clear', 'Rain', 'Drizzle', 'Mist', 'Haze', 'Fog',
#        'Thunderstorm', 'Snow', 'Squall', 'Smoke'], dtype=object)

# %%
df['clouds_all'].unique()
# Out:
# array([ 40,  75,  90,   1,  20,   0, 100,  92,  99,  81,  50,  72,  56,
#         57,  93,  85,  68,  87,  91,  96,  48,  60,   8,  38,  46,  98,
#         86,  16,   6,  59,  54,  89,  78,  36,  17,  58,  63,  42,  25,
#         11,  13,  83,  70,  84,   3,  77,  88,  67,  97,  62,  32,   4,
#          5,   2,  44,  24,  76,  64,  80,  12])

# %%
df['humidity'].unique()
# Out:
# array([ 89,  67,  66,  65,  64,  63,  62,  61,  60,  59,  58,  57,  56,
#         55,  48,  42,  33,  30,  32,  37,  36,  39,  41,  44,  47,  50,
#         75,  70,  93,  84,  53,  49,  45,  28,  26,  34,  54,  71,  76,
#         35,  27,  25,  23,  24,  31,  52,  69,  80,  74,  38,  51,  79,
#         21,  43,  68,  87,  86,  29,  40,  92,  19,  18,  20,  81, 100,
#         46,  83,  85,  88,  90,  95,  97,  91,  78,  82,  72,  77,  73,
#         94,  96,  98,  17,  22,  99,  15,  16,  14,  13])

# %%
df['wind_speed'].unique()
# Out:
# array([ 2,  3,  4,  5,  7,  6,  0,  1,  9,  8, 10, 12, 11, 13, 15, 14, 16])

# %%
df['year'] = pd.DatetimeIndex(df['date_time']).year

# %%
df['month'] = pd.DatetimeIndex(df['date_time']).month

# %%
df.describe()

# %%
df['is_holiday'].unique()
# Out:
# array(['None', 'Columbus Day', 'Veterans Day', 'Thanksgiving Day',
#        'Christmas Day', 'New Years Day', 'Washingtons Birthday',
#        'Memorial Day', 'Independence Day', 'State Fair', 'Labor Day',
#        'Martin Luther King Jr Day'], dtype=object)

# %%
mapping = {'None':0, 'Columbus Day':1, 'Veterans Day':2, 'Thanksgiving Day':3,
       'Christmas Day':4, 'New Years Day':5, 'Washingtons Birthday':6,
       'Memorial Day':7, 'Independence Day':8, 'State Fair':9, 'Labor Day':10,
       'Martin Luther King Jr Day':11}
x_train.replace({'is_holiday': mapping})
# Out:
#        is_holiday  air_pollution_index  humidity  wind_speed  wind_direction  \
# 0               0                  121        89           2             329
# 1               0                  178        67           3             330
# 2               0                  113        66           3             329
# 3               0                   20        66           3             329
# 4               0                  281        65           3             329
# ...           ...                  ...       ...         ...             ...
# 33745           0                   74        85           1             328
# 33746           0                   81        70           1              24
# 33747           0                  138        70           1              24
# 33748           0                  229        66           1              42
# 33749           0                  140        63           1              27
#
# ...

# %%
x_train = df
y_train = df['traffic_volume']

# %%
x_train = x_train.drop(['traffic_volume','weather_description','date_time'],axis=1)

# %%
x_train
# Out:
#       is_holiday  air_pollution_index  humidity  wind_speed  wind_direction  \
# 0           None                  121        89           2             329
# 1           None                  178        67           3             330
# 2           None                  113        66           3             329
# 3           None                   20        66           3             329
# 4           None                  281        65           3             329
# ...          ...                  ...       ...         ...             ...
# 33745       None                   74        85           1             328
# 33746       None                   81        70           1              24
# 33747       None                  138        70           1              24
# 33748       None                  229        66           1              42
# 33749       None                  140        63           1              27
#
# ...

# %% [markdown]
# # Training using Linear Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()

# %%
model.fit(x_train, y_train)

# %%
model.score(x_train, y_train)

# %%
x_test = pd.read_csv('Test.csv')

# %%
x_test = x_test.drop(['is_holiday', 'weather_type', 'weather_description','date_time'],axis=1)

# %%
x_test

# %%
output = model.predict(x_test)

# %%
import requests

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

r = requests.post("https://httpbin.org/post", data=payload)
print(r.text)
